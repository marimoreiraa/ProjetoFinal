# %% [markdown]
# <a href="https://colab.research.google.com/github/MarianaDuartee/ProjetoFinal/blob/main/1_Apache_Beam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### INSTALANDO DEPENDENCIAS

# %%
# !pip install google-cloud-pubsub
# !pip install fsspec
# !pip install gcsfs
# !pip install apache-beam[interactive]
# !pip install apache_beam[gcp]
# !pip install google-cloud-bigquery

# %% [markdown]
# ### IMPORTANDO BIBLIOTECAS

# %%
import csv
import time
import os
import json
import argparse
import logging

import fsspec
import gcsfs
import pandas as pd

import apache_beam as beam
from apache_beam import coders
from apache_beam.io.gcp.internal.clients import bigquery
from apache_beam.options.pipeline_options import GoogleCloudOptions
from apache_beam.options.pipeline_options import PipelineOptions

from google.cloud import storage
from google.cloud import bigquery
from google.colab import drive
from google.oauth2 import service_account

# Configurando conta de serviço
service_account_key = r"/content/soulcode-projeto-final-4b88bea6e07a.json"
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = service_account_key

# %% [markdown]
# # PIPELINE BATCH

# %% [markdown]
# ### PIPELINE LOCAL PARA GCS

# %%
# Criando pipeline
p1 = beam.Pipeline()

# Modelo de Pipeline. Ingerindo arquivos locais

path_file = r'/content/drive/MyDrive/Projeto Final/OcorrenciasUF.json'

rows = (
    p1
    |'Extrair_Dados' >> beam.io.Read(path_file, skip_header_lines=0, coder=coders.StrUtf8Coder())
    |'Ler_Elementos' >> beam.Map(lambda element: element)
    # |'Separar_Elementos' >> beam.Map(lambda element: element.split(','))
    |'Gravar_resultado' >> beam.io.WriteToText('gs://data_lake_ingest_data/1_input/converter/OcorrenciasUF', file_name_suffix='.json')
   )

p1.run()

df_test = pd.read_json('gs://data_lake_ingest_data/1_input/converter/OcorrenciasUF-00000-of-00001.json')
print(df_test)
print(df_test.dtypes)

# %% [markdown]
# ### PIPELINE GCS PARA BIGQUERY (BATCH)

# %%
def create_table(element):
    dict_ = {} 
    dict_['UF'] = str(element[1])
    dict_['populacao_estimada'] = float(element[2])
    dict_['Ano'] = int(element[3])
    return(dict_)

def run(argv=None):
    """Run the workflow."""
    parser = argparse.ArgumentParser()

    parser.add_argument('--output', required=True,
    help=(
          'Output BigQuery table for results specified as: '
          'PROJECT:DATASET.TABLE or DATASET.TABLE.'))
    known_args, pipeline_args = parser.parse_known_args(argv)

    with beam.Pipeline(argv=pipeline_args) as p1:
        table_schema = bigquery.TableSchema()

        UF = bigquery.TableFieldSchema()
        UF.name = 'UF'
        UF.type = 'string'
        UF.mode = 'nullable'
        table_schema.fields.append(UF)

        populacao_estimada = bigquery.TableFieldSchema()
        populacao_estimada.name = 'populacao_estimada'
        populacao_estimada.type = 'float'
        populacao_estimada.mode = 'nullable'
        table_schema.fields.append(populacao_estimada)

        Ano = bigquery.TableFieldSchema()
        Ano.name = 'populacao_estimada'
        Ano.type = 'integer'
        Ano.mode = 'nullable'
        table_schema.fields.append(Ano)

pipeline_args={'runner':'DataflowRunner',
               'job_name':'bq-load',
               'project':'soulcode-projeto-final',
               'region':'southamerica-east1',
               'temp_location':'gs://data_lake_ingest_data/temp_process',
               'staging_location':'gs://data_lake_ingest_data/temp_process',
               'template_location':'gs://data_lake_ingest_data/4_templates/template_model_batch',
               'save_main_session':True,
               }

options = PipelineOptions.from_dictionary(pipeline_args)
p1 = beam.Pipeline(options=options)

p1 = beam.Pipeline()

path_file_input = 'gs://data_lake_ingest_data/2_temp/temp_pandas_total_pop_ano_uf.csv'
path_file_output = 'gs://data_lake_ingest_data/temp/temp_pandas_total_pop_ano_uf'

table_schema =[
                {
                    "mode": "NULLABLE",
                    "name": "UF",
                    "type": "STRING"
                },
                {
                    "mode": "NULLABLE",
                    "name": "populacao_estimada",
                    "type": "STRING"
                },
                {
                    "mode": "NULLABLE",
                    "name": "Ano",
                    "type": "INTEGER"
                }
            ]

schema = json.dumps(table_schema)

pass_to_table = (
        p1 

        |'Extraindo_Dados' >> beam.io.ReadFromText(path_file_input, skip_header_lines=1)
        |'Separar_Elementos' >> beam.Map(lambda element: element.split(','))
        |'Criar_Tabela' >> beam.Map(lambda element: create_table(element))
        |'Print' >> beam.Map(lambda element: print(element))
        |'Gravar_resultado' >> beam.io.WriteToText(path_file_output, file_name_suffix='.csv', header=True)
        |'Gravar_Resultado' >> beam.io.WriteToBigQuery(
                                    table='TesteBeamApache',
                                    dataset='Teste',
                                    project='soulcode-projeto-final',
                                    custom_gcs_temp_location='gs://data_lake_ingest_data/temp_process',
                                    schema=schema,
                                    create_disposition=beam.io.BigQueryDisposition.CREATE_IF_NEEDED,
                                    write_disposition=beam.io.BigQueryDisposition.WRITE_TRUNCATE)
        )

p1.run().wait_until_finish()
# Out:
# WARNING:root:Make sure that locally built Python SDK docker image has Python 3.7 interpreter.
# {'UF': 'AC', 'populacao_estimada': 816687.0, 'Ano': 2016}
# {'UF': 'AL', 'populacao_estimada': 3358963.0, 'Ano': 2016}
# {'UF': 'AM', 'populacao_estimada': 4001667.0, 'Ano': 2016}
# {'UF': 'AP', 'populacao_estimada': 782295.0, 'Ano': 2016}
# {'UF': 'BA', 'populacao_estimada': 15276566.0, 'Ano': 2016}
# {'UF': 'CE', 'populacao_estimada': 8963663.0, 'Ano': 2016}
# {'UF': 'DF', 'populacao_estimada': 2977216.0, 'Ano': 2016}
# {'UF': 'ES', 'populacao_estimada': 3973697.0, 'Ano': 2016}
# {'UF': 'GO', 'populacao_estimada': 6695855.0, 'Ano': 2016}
# {'UF': 'MA', 'populacao_estimada': 6954036.0, 'Ano': 2016}
# {'UF': 'MG', 'populacao_estimada': 20997560.0, 'Ano': 2016}
# {'UF': 'MS', 'populacao_estimada': 2682386.0, 'Ano': 2016}
# {'UF': 'MT', 'populacao_estimada': 3305531.0, 'Ano': 2016}
# {'UF': 'PA', 'populacao_estimada': 8305359.0, 'Ano': 2016}
# {'UF': 'PB', 'populacao_estimada': 3999415.0, 'Ano': 2016}
# {'UF': 'PE', 'populacao_estimada': 9410336.0, 'Ano': 2016}
# {'UF': 'PI', 'populacao_estimada': 3212180.0, 'Ano': 2016}
# {'UF': 'PR', 'populacao_estimada': 11242720.0, 'Ano': 2016}
# {'UF': 'RJ', 'populacao_estimada': 16635996.0, 'Ano': 2016}
# {'UF': 'RN', 'populacao_estimada': 3474998.0, 'Ano': 2016}
# {'UF': 'RO', 'populacao_estimada': 1787279.0, 'Ano': 2016}
# {'UF': 'RR', 'populacao_estimada': 514229.0, 'Ano': 2016}
# {'UF': 'RS', 'populacao_estimada': 11286500.0, 'Ano': 2016}
# {'UF': 'SC', 'populacao_estimada': 6910553.0, 'Ano': 2016}
# {'UF': 'SE', 'populacao_estimada': 2265779.0, 'Ano': 2016}
# {'UF': 'SP', 'populacao_estimada': 44749699.0, 'Ano': 2016}
# {'UF': 'TO', 'populacao_estimada': 1532902.0, 'Ano': 2016}
# {'UF': 'AC', 'populacao_estimada': 829619.0, 'Ano': 2017}
# {'UF': 'AL', 'populacao_estimada': 3375823.0, 'Ano': 2017}
# {'UF': 'AM', 'populacao_estimada': 4063614.0, 'Ano': 2017}
# {'UF': 'AP', 'populacao_estimada': 797722.0, 'Ano': 2017}
# {'UF': 'BA', 'populacao_estimada': 15344447.0, 'Ano': 2017}
# {'UF': 'CE', 'populacao_estimada': 9020460.0, 'Ano': 2017}
# {'UF': 'DF', 'populacao_estimada': 3039444.0, 'Ano': 2017}
# {'UF': 'ES', 'populacao_estimada': 4016356.0, 'Ano': 2017}
# {'UF': 'GO', 'populacao_estimada': 6778772.0, 'Ano': 2017}
# {'UF': 'MA', 'populacao_estimada': 7000229.0, 'Ano': 2017}
# {'UF': 'MG', 'populacao_estimada': 21119536.0, 'Ano': 2017}
# {'UF': 'MS', 'populacao_estimada': 2713147.0, 'Ano': 2017}
# {'UF': 'MT', 'populacao_estimada': 3344544.0, 'Ano': 2017}
# {'UF': 'PA', 'populacao_estimada': 8366628.0, 'Ano': 2017}
# {'UF': 'PB', 'populacao_estimada': 4025558.0, 'Ano': 2017}
# {'UF': 'PE', 'populacao_estimada': 9473266.0, 'Ano': 2017}
# {'UF': 'PI', 'populacao_estimada': 3219257.0, 'Ano': 2017}
# {'UF': 'PR', 'populacao_estimada': 11320892.0, 'Ano': 2017}
# {'UF': 'RJ', 'populacao_estimada': 16718956.0, 'Ano': 2017}
# {'UF': 'RN', 'populacao_estimada': 3507003.0, 'Ano': 2017}
# {'UF': 'RO', 'populacao_estimada': 1805788.0, 'Ano': 2017}
# {'UF': 'RR', 'populacao_estimada': 522636.0, 'Ano': 2017}
# {'UF': 'RS', 'populacao_estimada': 11322895.0, 'Ano': 2017}
# {'UF': 'SC', 'populacao_estimada': 7001161.0, 'Ano': 2017}
# {'UF': 'SE', 'populacao_estimada': 2288116.0, 'Ano': 2017}
# {'UF': 'SP', 'populacao_estimada': 45094866.0, 'Ano': 2017}
# {'UF': 'TO', 'populacao_estimada': 1550194.0, 'Ano': 2017}
# {'UF': 'AC', 'populacao_estimada': 869265.0, 'Ano': 2018}
# {'UF': 'AL', 'populacao_estimada': 3322820.0, 'Ano': 2018}
# {'UF': 'AM', 'populacao_estimada': 4080611.0, 'Ano': 2018}
# {'UF': 'AP', 'populacao_estimada': 829494.0, 'Ano': 2018}
# {'UF': 'BA', 'populacao_estimada': 14812617.0, 'Ano': 2018}
# {'UF': 'CE', 'populacao_estimada': 9075649.0, 'Ano': 2018}
# {'UF': 'DF', 'populacao_estimada': 2974703.0, 'Ano': 2018}
# {'UF': 'ES', 'populacao_estimada': 3972388.0, 'Ano': 2018}
# {'UF': 'GO', 'populacao_estimada': 6921161.0, 'Ano': 2018}
# {'UF': 'MA', 'populacao_estimada': 7035055.0, 'Ano': 2018}
# {'UF': 'MG', 'populacao_estimada': 21040662.0, 'Ano': 2018}
# {'UF': 'MS', 'populacao_estimada': 2748023.0, 'Ano': 2018}
# {'UF': 'MT', 'populacao_estimada': 3441998.0, 'Ano': 2018}
# {'UF': 'PA', 'populacao_estimada': 8513497.0, 'Ano': 2018}
# {'UF': 'PB', 'populacao_estimada': 3996496.0, 'Ano': 2018}
# {'UF': 'PE', 'populacao_estimada': 9496294.0, 'Ano': 2018}
# {'UF': 'PI', 'populacao_estimada': 3264531.0, 'Ano': 2018}
# {'UF': 'PR', 'populacao_estimada': 11348937.0, 'Ano': 2018}
# {'UF': 'RJ', 'populacao_estimada': 17159960.0, 'Ano': 2018}
# {'UF': 'RN', 'populacao_estimada': 3479010.0, 'Ano': 2018}
# {'UF': 'RO', 'populacao_estimada': 1757589.0, 'Ano': 2018}
# {'UF': 'RR', 'populacao_estimada': 576568.0, 'Ano': 2018}
# {'UF': 'RS', 'populacao_estimada': 11329605.0, 'Ano': 2018}
# {'UF': 'SC', 'populacao_estimada': 7075494.0, 'Ano': 2018}
# {'UF': 'SE', 'populacao_estimada': 2278308.0, 'Ano': 2018}
# {'UF': 'SP', 'populacao_estimada': 45538936.0, 'Ano': 2018}
# {'UF': 'TO', 'populacao_estimada': 1555229.0, 'Ano': 2018}
# {'UF': 'AC', 'populacao_estimada': 881935.0, 'Ano': 2019}
# {'UF': 'AL', 'populacao_estimada': 3337357.0, 'Ano': 2019}
# {'UF': 'AM', 'populacao_estimada': 4144597.0, 'Ano': 2019}
# {'UF': 'AP', 'populacao_estimada': 845731.0, 'Ano': 2019}
# {'UF': 'BA', 'populacao_estimada': 14873064.0, 'Ano': 2019}
# {'UF': 'CE', 'populacao_estimada': 9132078.0, 'Ano': 2019}
# {'UF': 'DF', 'populacao_estimada': 3015268.0, 'Ano': 2019}
# {'UF': 'ES', 'populacao_estimada': 4018650.0, 'Ano': 2019}
# {'UF': 'GO', 'populacao_estimada': 7018354.0, 'Ano': 2019}
# {'UF': 'MA', 'populacao_estimada': 7075181.0, 'Ano': 2019}
# {'UF': 'MG', 'populacao_estimada': 21168791.0, 'Ano': 2019}
# {'UF': 'MS', 'populacao_estimada': 2778986.0, 'Ano': 2019}
# {'UF': 'MT', 'populacao_estimada': 3484466.0, 'Ano': 2019}
# {'UF': 'PA', 'populacao_estimada': 8602865.0, 'Ano': 2019}
# {'UF': 'PB', 'populacao_estimada': 4018127.0, 'Ano': 2019}
# {'UF': 'PE', 'populacao_estimada': 9557071.0, 'Ano': 2019}
# {'UF': 'PI', 'populacao_estimada': 3273227.0, 'Ano': 2019}
# {'UF': 'PR', 'populacao_estimada': 11433957.0, 'Ano': 2019}
# {'UF': 'RJ', 'populacao_estimada': 17264943.0, 'Ano': 2019}
# {'UF': 'RN', 'populacao_estimada': 3506853.0, 'Ano': 2019}
# {'UF': 'RO', 'populacao_estimada': 1777225.0, 'Ano': 2019}
# {'UF': 'RR', 'populacao_estimada': 605761.0, 'Ano': 2019}
# {'UF': 'RS', 'populacao_estimada': 11377239.0, 'Ano': 2019}
# {'UF': 'SC', 'populacao_estimada': 7164788.0, 'Ano': 2019}
# {'UF': 'SE', 'populacao_estimada': 2298696.0, 'Ano': 2019}
# {'UF': 'SP', 'populacao_estimada': 45919049.0, 'Ano': 2019}
# {'UF': 'TO', 'populacao_estimada': 1572866.0, 'Ano': 2019}
# {'UF': 'AC', 'populacao_estimada': 894470.0, 'Ano': 2020}
# {'UF': 'AL', 'populacao_estimada': 3351543.0, 'Ano': 2020}
# {'UF': 'AM', 'populacao_estimada': 4207714.0, 'Ano': 2020}
# {'UF': 'AP', 'populacao_estimada': 861773.0, 'Ano': 2020}
# {'UF': 'BA', 'populacao_estimada': 14930634.0, 'Ano': 2020}
# {'UF': 'CE', 'populacao_estimada': 9187103.0, 'Ano': 2020}
# {'UF': 'DF', 'populacao_estimada': 3055149.0, 'Ano': 2020}
# {'UF': 'ES', 'populacao_estimada': 4064052.0, 'Ano': 2020}
# {'UF': 'GO', 'populacao_estimada': 7113540.0, 'Ano': 2020}
# {'UF': 'MA', 'populacao_estimada': 7114598.0, 'Ano': 2020}
# {'UF': 'MG', 'populacao_estimada': 21292666.0, 'Ano': 2020}
# {'UF': 'MS', 'populacao_estimada': 2809394.0, 'Ano': 2020}
# {'UF': 'MT', 'populacao_estimada': 3526220.0, 'Ano': 2020}
# {'UF': 'PA', 'populacao_estimada': 8690745.0, 'Ano': 2020}
# {'UF': 'PB', 'populacao_estimada': 4039277.0, 'Ano': 2020}
# {'UF': 'PE', 'populacao_estimada': 9616621.0, 'Ano': 2020}
# {'UF': 'PI', 'populacao_estimada': 3281480.0, 'Ano': 2020}
# {'UF': 'PR', 'populacao_estimada': 11516840.0, 'Ano': 2020}
# {'UF': 'RJ', 'populacao_estimada': 17366189.0, 'Ano': 2020}
# {'UF': 'RN', 'populacao_estimada': 3534165.0, 'Ano': 2020}
# {'UF': 'RO', 'populacao_estimada': 1796460.0, 'Ano': 2020}
# {'UF': 'RR', 'populacao_estimada': 631181.0, 'Ano': 2020}
# {'UF': 'RS', 'populacao_estimada': 11422973.0, 'Ano': 2020}
# {'UF': 'SC', 'populacao_estimada': 7252502.0, 'Ano': 2020}
# {'UF': 'SE', 'populacao_estimada': 2318822.0, 'Ano': 2020}
# {'UF': 'SP', 'populacao_estimada': 46289333.0, 'Ano': 2020}
# {'UF': 'TO', 'populacao_estimada': 1590248.0, 'Ano': 2020}
# {'UF': 'AC', 'populacao_estimada': 906876.0, 'Ano': 2021}
# {'UF': 'AL', 'populacao_estimada': 3365351.0, 'Ano': 2021}
# {'UF': 'AM', 'populacao_estimada': 4269995.0, 'Ano': 2021}
# {'UF': 'AP', 'populacao_estimada': 877613.0, 'Ano': 2021}
# {'UF': 'BA', 'populacao_estimada': 14985284.0, 'Ano': 2021}
# {'UF': 'CE', 'populacao_estimada': 9240580.0, 'Ano': 2021}
# {'UF': 'DF', 'populacao_estimada': 3094325.0, 'Ano': 2021}
# {'UF': 'ES', 'populacao_estimada': 4108508.0, 'Ano': 2021}
# {'UF': 'GO', 'populacao_estimada': 7206589.0, 'Ano': 2021}
# {'UF': 'MA', 'populacao_estimada': 7153262.0, 'Ano': 2021}
# {'UF': 'MG', 'populacao_estimada': 21411923.0, 'Ano': 2021}
# {'UF': 'MS', 'populacao_estimada': 2839188.0, 'Ano': 2021}
# {'UF': 'MT', 'populacao_estimada': 3567234.0, 'Ano': 2021}
# {'UF': 'PA', 'populacao_estimada': 8777124.0, 'Ano': 2021}
# {'UF': 'PB', 'populacao_estimada': 4059905.0, 'Ano': 2021}
# {'UF': 'PE', 'populacao_estimada': 9674793.0, 'Ano': 2021}
# {'UF': 'PI', 'populacao_estimada': 3289290.0, 'Ano': 2021}
# {'UF': 'PR', 'populacao_estimada': 11597484.0, 'Ano': 2021}
# {'UF': 'RJ', 'populacao_estimada': 17463349.0, 'Ano': 2021}
# {'UF': 'RN', 'populacao_estimada': 3560903.0, 'Ano': 2021}
# {'UF': 'RO', 'populacao_estimada': 1815278.0, 'Ano': 2021}
# {'UF': 'RR', 'populacao_estimada': 652713.0, 'Ano': 2021}
# {'UF': 'RS', 'populacao_estimada': 11466630.0, 'Ano': 2021}
# {'UF': 'SC', 'populacao_estimada': 7338473.0, 'Ano': 2021}
# {'UF': 'SE', 'populacao_estimada': 2338474.0, 'Ano': 2021}
# {'UF': 'SP', 'populacao_estimada': 46649132.0, 'Ano': 2021}
# {'UF': 'TO', 'populacao_estimada': 1607363.0, 'Ano': 2021}
# WARNING:apache_beam.io.filebasedsink:Deleting 1 existing files in target path matching: -*-of-%(num_shards)05d
# ---------------------------------------------------------------------------
# HttpBadRequestError                       Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/apache_beam/runners/common.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.common.DoFnRunner.process()
#
# /usr/local/lib/python3.7/dist-packages/apache_beam/runners/common.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.common.PerWindowInvoker.invoke_process()
#
# /usr/local/lib/python3.7/dist-packages/apache_beam/runners/common.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.common.PerWindowInvoker._invoke_process_per_window()
#
# /usr/local/lib/python3.7/dist-packages/apache_beam/runners/common.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.common._OutputProcessor.process_outputs()
#
# /usr/local/lib/python3.7/dist-packages/apache_beam/io/gcp/bigquery_file_loads.py in process(self, element, load_job_name_prefix, *schema_side_inputs)
#     665         source_format=self.source_format,
# --> 666         job_labels=self.bq_io_metadata.add_additional_bq_job_labels())
#     667     yield (destination, job_reference)
#
# /usr/local/lib/python3.7/dist-packages/apache_beam/io/gcp/bigquery_tools.py in perform_load_job(self, destination, job_id, source_uris, source_stream, schema, write_disposition, create_disposition, additional_load_parameters, source_format, job_labels)
#    1016         source_format=source_format,
# -> 1017         job_labels=job_labels)
#    1018
#
# /usr/local/lib/python3.7/dist-packages/apache_beam/utils/retry.py in wrapper(*args, **kwargs)
#     252         try:
# --> 253           return fun(*args, **kwargs)
#     254         except Exception as exn:  # pylint: disable=broad-except
#
# /usr/local/lib/python3.7/dist-packages/apache_beam/io/gcp/bigquery_tools.py in _insert_load_job(self, project_id, job_id, table_reference, source_uris, source_stream, schema, write_disposition, create_disposition, additional_load_parameters, source_format, job_labels)
#     531         ))
# --> 532     return self._start_job(request, stream=source_stream).jobReference
#     533
#
# /usr/local/lib/python3.7/dist-packages/apache_beam/io/gcp/bigquery_tools.py in _start_job(self, request, stream)
#     550         upload = Upload.FromStream(stream, mime_type=UNKNOWN_MIME_TYPE)
# --> 551       response = self.client.jobs.Insert(request, upload=upload)
#     552       _LOGGER.info(
#
# /usr/local/lib/python3.7/dist-packages/apache_beam/io/gcp/internal/clients/bigquery/bigquery_v2_client.py in Insert(self, request, global_params, upload)
#     344           config, request, global_params=global_params,
# --> 345           upload=upload, upload_config=upload_config)
#     346
#
# /usr/local/lib/python3.7/dist-packages/apitools/base/py/base_api.py in _RunMethod(self, method_config, request, global_params, upload, upload_config, download)
#     730
# --> 731         return self.ProcessHttpResponse(method_config, http_response, request)
#     732
#
# /usr/local/lib/python3.7/dist-packages/apitools/base/py/base_api.py in ProcessHttpResponse(self, method_config, http_response, request)
#     736             method_config,
# --> 737             self.__ProcessHttpResponse(method_config, http_response, request))
#
# /usr/local/lib/python3.7/dist-packages/apitools/base/py/base_api.py in __ProcessHttpResponse(self, method_config, http_response, request)
#     603             raise exceptions.HttpError.FromResponse(
# --> 604                 http_response, method_config=method_config, request=request)
#     605         if http_response.status_code == http_client.NO_CONTENT:
#
# HttpBadRequestError: HttpError accessing <https://bigquery.googleapis.com/bigquery/v2/projects/soulcode-projeto-final/jobs?alt=json>: response: <{'vary': 'Origin, X-Origin, Referer', 'content-type': 'application/json; charset=UTF-8', 'date': 'Tue, 30 Nov 2021 05:35:01 GMT', 'server': 'ESF', 'cache-control': 'private', 'x-xss-protection': '0', 'x-frame-options': 'SAMEORIGIN', 'x-content-type-options': 'nosniff', 'transfer-encoding': 'chunked', 'status': '400', 'content-length': '312', '-content-encoding': 'gzip'}>, content <{
#   "error": {
#     "code": 400,
#     "message": "Invalid value for type:  \"UF\" is not a valid value",
#     "errors": [
#       {
#         "message": "Invalid value for type:  \"UF\" is not a valid value",
#         "domain": "global",
#         "reason": "invalid"
#       }
#     ],
#     "status": "INVALID_ARGUMENT"
#   }
# }
# >
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-190-91d502b3c1e8> in <module>
#      90         )
#      91
# ---> 92 p1.run().wait_until_finish()
#
# /usr/local/lib/python3.7/dist-packages/apache_beam/pipeline.py in run(self, test_runner_api)
#     571         finally:
#     572           shutil.rmtree(tmpdir)
# --> 573       return self.runner.run_pipeline(self, self._options)
#     574     finally:
#     575       if not is_in_ipython():
#
# /usr/local/lib/python3.7/dist-packages/apache_beam/runners/direct/direct_runner.py in run_pipeline(self, pipeline, options)
#     129       runner = BundleBasedDirectRunner()
#     130
# --> 131     return runner.run_pipeline(pipeline, options)
#     132
#     133
#
# /usr/local/lib/python3.7/dist-packages/apache_beam/runners/portability/fn_api_runner/fn_runner.py in run_pipeline(self, pipeline, options)
#     194
#     195     self._latest_run_result = self.run_via_runner_api(
# --> 196         pipeline.to_runner_api(default_environment=self._default_environment))
#     197     return self._latest_run_result
#     198
#
# /usr/local/lib/python3.7/dist-packages/apache_beam/runners/portability/fn_api_runner/fn_runner.py in run_via_runner_api(self, pipeline_proto)
#     204     # TODO(pabloem, BEAM-7514): Create a watermark manager (that has access to
#     205     #   the teststream (if any), and all the stages).
# --> 206     return self.run_stages(stage_context, stages)
#     207
#     208   @contextlib.contextmanager
#
# /usr/local/lib/python3.7/dist-packages/apache_beam/runners/portability/fn_api_runner/fn_runner.py in run_stages(self, stage_context, stages)
#     383
#     384           stage_results = self._run_stage(
# --> 385               runner_execution_context, bundle_context_manager)
#     386
#     387           assert (
#
# /usr/local/lib/python3.7/dist-packages/apache_beam/runners/portability/fn_api_runner/fn_runner.py in _run_stage(self, runner_execution_context, bundle_context_manager)
#     651               input_timers,
#     652               expected_timer_output,
# --> 653               bundle_manager))
#     654
#     655       for pc_name, watermark in watermark_updates.items():
#
# /usr/local/lib/python3.7/dist-packages/apache_beam/runners/portability/fn_api_runner/fn_runner.py in _run_bundle(self, runner_execution_context, bundle_context_manager, data_input, data_output, input_timers, expected_timer_output, bundle_manager)
#     768
#     769     result, splits = bundle_manager.process_bundle(
# --> 770         data_input, data_output, input_timers, expected_timer_output)
#     771     # Now we collect all the deferred inputs remaining from bundle execution.
#     772     # Deferred inputs can be:
#
# /usr/local/lib/python3.7/dist-packages/apache_beam/runners/portability/fn_api_runner/fn_runner.py in process_bundle(self, inputs, expected_outputs, fired_timers, expected_output_timers, dry_run)
#    1078             process_bundle_descriptor.id,
#    1079             cache_tokens=[next(self._cache_token_generator)]))
# -> 1080     result_future = self._worker_handler.control_conn.push(process_bundle_req)
#    1081
#    1082     split_results = []  # type: List[beam_fn_api_pb2.ProcessBundleSplitResponse]
#
# /usr/local/lib/python3.7/dist-packages/apache_beam/runners/portability/fn_api_runner/worker_handlers.py in push(self, request)
#     376       self._uid_counter += 1
#     377       request.instruction_id = 'control_%s' % self._uid_counter
# --> 378     response = self.worker.do_instruction(request)
#     379     return ControlFuture(request.instruction_id, response)
#     380
#
# /usr/local/lib/python3.7/dist-packages/apache_beam/runners/worker/sdk_worker.py in do_instruction(self, request)
#     596       # E.g. if register is set, this will call self.register(request.register))
#     597       return getattr(self, request_type)(
# --> 598           getattr(request, request_type), request.instruction_id)
#     599     else:
#     600       raise NotImplementedError
#
# /usr/local/lib/python3.7/dist-packages/apache_beam/runners/worker/sdk_worker.py in process_bundle(self, request, instruction_id)
#     633         with self.maybe_profile(instruction_id):
#     634           delayed_applications, requests_finalization = (
# --> 635               bundle_processor.process_bundle(instruction_id))
#     636           monitoring_infos = bundle_processor.monitoring_infos()
#     637           monitoring_infos.extend(self.state_cache_metrics_fn())
#
# /usr/local/lib/python3.7/dist-packages/apache_beam/runners/worker/bundle_processor.py in process_bundle(self, instruction_id)
#     994           elif isinstance(element, beam_fn_api_pb2.Elements.Data):
#     995             input_op_by_transform_id[element.transform_id].process_encoded(
# --> 996                 element.data)
#     997
#     998       # Finish all operations.
#
# /usr/local/lib/python3.7/dist-packages/apache_beam/runners/worker/bundle_processor.py in process_encoded(self, encoded_windowed_values)
#     219       decoded_value = self.windowed_coder_impl.decode_from_stream(
#     220           input_stream, True)
# --> 221       self.output(decoded_value)
#     222
#     223   def monitoring_infos(self, transform_id, tag_to_pcollection_id):
#
# /usr/local/lib/python3.7/dist-packages/apache_beam/runners/worker/operations.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.worker.operations.Operation.output()
#
# /usr/local/lib/python3.7/dist-packages/apache_beam/runners/worker/operations.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.worker.operations.Operation.output()
#
# /usr/local/lib/python3.7/dist-packages/apache_beam/runners/worker/operations.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.worker.operations.SingletonConsumerSet.receive()
#
# /usr/local/lib/python3.7/dist-packages/apache_beam/runners/worker/operations.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.worker.operations.DoOperation.process()
#
# /usr/local/lib/python3.7/dist-packages/apache_beam/runners/worker/operations.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.worker.operations.DoOperation.process()
#
# /usr/local/lib/python3.7/dist-packages/apache_beam/runners/common.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.common.DoFnRunner.process()
#
# /usr/local/lib/python3.7/dist-packages/apache_beam/runners/common.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.common.DoFnRunner._reraise_augmented()
#
# /usr/local/lib/python3.7/dist-packages/apache_beam/runners/common.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.common.DoFnRunner.process()
#
# /usr/local/lib/python3.7/dist-packages/apache_beam/runners/common.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.common.SimpleInvoker.invoke_process()
#
# /usr/local/lib/python3.7/dist-packages/apache_beam/runners/common.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.common._OutputProcessor.process_outputs()
#
# /usr/local/lib/python3.7/dist-packages/apache_beam/runners/worker/operations.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.worker.operations.SingletonConsumerSet.receive()
#
# /usr/local/lib/python3.7/dist-packages/apache_beam/runners/worker/operations.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.worker.operations.SingletonConsumerSet.receive()
#
# /usr/local/lib/python3.7/dist-packages/apache_beam/runners/worker/operations.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.worker.operations.DoOperation.process()
#
# /usr/local/lib/python3.7/dist-packages/apache_beam/runners/worker/operations.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.worker.operations.DoOperation.process()
#
# /usr/local/lib/python3.7/dist-packages/apache_beam/runners/common.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.common.DoFnRunner.process()
#
# /usr/local/lib/python3.7/dist-packages/apache_beam/runners/common.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.common.DoFnRunner._reraise_augmented()
#
# /usr/local/lib/python3.7/dist-packages/apache_beam/runners/common.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.common.DoFnRunner.process()
#
# /usr/local/lib/python3.7/dist-packages/apache_beam/runners/common.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.common.PerWindowInvoker.invoke_process()
#
# /usr/local/lib/python3.7/dist-packages/apache_beam/runners/common.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.common.PerWindowInvoker._invoke_process_per_window()
#
# /usr/local/lib/python3.7/dist-packages/apache_beam/runners/common.cpython-37m-x86_64-linux-gnu.so in apache_beam.runners.common._OutputProcessor.process_outputs()
#
# /usr/local/lib/python3.7/dist-packages/apache_beam/io/gcp/bigquery_file_loads.py in process(self, element, load_job_name_prefix, *schema_side_inputs)
#     664         additional_load_parameters=additional_parameters,
#     665         source_format=self.source_format,
# --> 666         job_labels=self.bq_io_metadata.add_additional_bq_job_labels())
#     667     yield (destination, job_reference)
#     668
#
# /usr/local/lib/python3.7/dist-packages/apache_beam/io/gcp/bigquery_tools.py in perform_load_job(self, destination, job_id, source_uris, source_stream, schema, write_disposition, create_disposition, additional_load_parameters, source_format, job_labels)
#    1015         additional_load_parameters=additional_load_parameters,
#    1016         source_format=source_format,
# -> 1017         job_labels=job_labels)
#    1018
#    1019   @retry.with_exponential_backoff(
#
# /usr/local/lib/python3.7/dist-packages/apache_beam/utils/retry.py in wrapper(*args, **kwargs)
#     251       while True:
#     252         try:
# --> 253           return fun(*args, **kwargs)
#     254         except Exception as exn:  # pylint: disable=broad-except
#     255           if not retry_filter(exn):
#
# /usr/local/lib/python3.7/dist-packages/apache_beam/io/gcp/bigquery_tools.py in _insert_load_job(self, project_id, job_id, table_reference, source_uris, source_stream, schema, write_disposition, create_disposition, additional_load_parameters, source_format, job_labels)
#     530             jobReference=reference,
#     531         ))
# --> 532     return self._start_job(request, stream=source_stream).jobReference
#     533
#     534   def _start_job(
#
# /usr/local/lib/python3.7/dist-packages/apache_beam/io/gcp/bigquery_tools.py in _start_job(self, request, stream)
#     549       if stream:
#     550         upload = Upload.FromStream(stream, mime_type=UNKNOWN_MIME_TYPE)
# --> 551       response = self.client.jobs.Insert(request, upload=upload)
#     552       _LOGGER.info(
#     553           "Started BigQuery job: %s\n "
#
# /usr/local/lib/python3.7/dist-packages/apache_beam/io/gcp/internal/clients/bigquery/bigquery_v2_client.py in Insert(self, request, global_params, upload)
#     343       return self._RunMethod(
#     344           config, request, global_params=global_params,
# --> 345           upload=upload, upload_config=upload_config)
#     346
#     347     Insert.method_config = lambda: base_api.ApiMethodInfo(
#
# /usr/local/lib/python3.7/dist-packages/apitools/base/py/base_api.py in _RunMethod(self, method_config, request, global_params, upload, upload_config, download)
#     729                 http, http_request, **opts)
#     730
# --> 731         return self.ProcessHttpResponse(method_config, http_response, request)
#     732
#     733     def ProcessHttpResponse(self, method_config, http_response, request=None):
#
# /usr/local/lib/python3.7/dist-packages/apitools/base/py/base_api.py in ProcessHttpResponse(self, method_config, http_response, request)
#     735         return self.__client.ProcessResponse(
#     736             method_config,
# --> 737             self.__ProcessHttpResponse(method_config, http_response, request))
#
# /usr/local/lib/python3.7/dist-packages/apitools/base/py/base_api.py in __ProcessHttpResponse(self, method_config, http_response, request)
#     602                                              http_client.NO_CONTENT):
#     603             raise exceptions.HttpError.FromResponse(
# --> 604                 http_response, method_config=method_config, request=request)
#     605         if http_response.status_code == http_client.NO_CONTENT:
#     606             # TODO(craigcitro): Find out why _replace doesn't seem to work
#
# RuntimeError: apitools.base.py.exceptions.HttpBadRequestError: HttpError accessing <https://bigquery.googleapis.com/bigquery/v2/projects/soulcode-projeto-final/jobs?alt=json>: response: <{'vary': 'Origin, X-Origin, Referer', 'content-type': 'application/json; charset=UTF-8', 'date': 'Tue, 30 Nov 2021 05:35:01 GMT', 'server': 'ESF', 'cache-control': 'private', 'x-xss-protection': '0', 'x-frame-options': 'SAMEORIGIN', 'x-content-type-options': 'nosniff', 'transfer-encoding': 'chunked', 'status': '400', 'content-length': '312', '-content-encoding': 'gzip'}>, content <{
#   "error": {
#     "code": 400,
#     "message": "Invalid value for type:  \"UF\" is not a valid value",
#     "errors": [
#       {
#         "message": "Invalid value for type:  \"UF\" is not a valid value",
#         "domain": "global",
#         "reason": "invalid"
#       }
#     ],
#     "status": "INVALID_ARGUMENT"
#   }
# }
# > [while running '[190]: Gravar_Resultado/BigQueryBatchFileLoads/TriggerLoadJobsWithoutTempTables']
